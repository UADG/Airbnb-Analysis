# %% [markdown]
# # รายชื่อสมาชิก

# %% [markdown]
# 6510450160 นายกวินท์ สินธพสิริพร\
#  หน้าที่ รวบรวมและคัดเลือก Data, เขียนอธิบายรายละเอียดแต่ละขั้นตอน, หาความสัมพันธ์เชิงเส้นและทิศทางของข้อมูล (Insight analysis)\
# 6510450976 นายศุภณัฐ สร้อยเพชร\
#  หน้าที่ Hindsight analysis eg. Data distribution, ทดสอบสมมติฐาน (Insight analysis)\
# 6510451131 นายอิทธิกร อึงนิยม\
#  หน้าที่ รวบรวมและคัดเลือก Data, cleaning dataset, วิเคราะห์ค่าเฉลี่ยของกลุ่มข้อมูลที่น่าสนใจ (Insight analysis)

# %% [markdown]
# ### อธิบาย

# %% [markdown]
# - Dataset Airbnb ครอบคลุมสถานที่ต่างๆ คอลเลกชั่นนี้ให้ข้อมูลเชิงลึก เกี่ยวกับตัวเลือกที่พักประเภทต่างๆ ที่มีให้บริการบนแพลตฟอร์ม Airbnb ด้วยข้อมูลที่ครอบคลุมเกี่ยวกับคุณสมบัติของที่พัก ราคา รีวิว และลักษณะของเจ้าของที่พัก สนองความอยากรู้อยากเห็นเกี่ยวกับแนวโน้มการเดินทางทั่วโลก
# - Data Sets จาก : Airbnb_Data ( https://www.kaggle.com/datasets/lovishbansal123/airbnb-data/data ) รวบรวมโดย LOVISH BANSAL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### คำอธิบายข้อมูล

# %% [markdown]
# - id คือ รหัสสมาชิกของเจ้าของที่พักอาศัยที่อยู่ในเว็ป (int64)
# - log_price คือ ราคาที่พักที่ถูกบันทึกไว้ (float64)
# - property_type คือ ประเภทของที่พัก (object)
# - room_type คือ ประเภทของห้องพัก (object)
# - amenities คือ สิ่งอำนวยความสะดวกในที่พัก (object)
# - accommodates คือ จำนวนที่รับรองรับคนมาพัก (int64)
# - bathrooms คือ จำนวนห้องน้ำ (float64)
# - bed_type คือ ประเภทของเตียงนอน (object)
# - cancellation_policy คือ เงื่อนไขยกเลิกการจอง (object)
# - cleaning_fee คือ ค่าธรรมเนียมทำความสะอาด (bool)
# - city คือ เมืองที่ที่พักตั้งอยู่ (object)
# - description คือ คำอธิบายเกี่ยวกับที่พัก (object)
# - first_review คือ วันเวลาที่มีคนรีวิวที่พักครั้งแรก (object)
# - host_has_profile_pic คือ เจ้าของที่พักที่มีรูปภาพ (object)
# - host_identity_verified คือ เจ้าของที่พักที่ยืนยันตัวตน (object)
# - host_response_rate คือ อัตราการตอบกลับของเจ้าของที่พัก (object)
# - host_since คือ วันเวลาที่เจ้าของที่พักสมัครสมาชิกครั้งแรก (object)
# - instant_bookable คือ ที่พักสามารถจองทันทีได้ไหม (object)
# - latitude คือ ละติจูดของที่พักมีค่าเท่าไหร่ (float64)
# - longitude คือ ลองติจูดของที่พักมีค่าเท่าไหร่ (float64)
# - last_review คือ วันเวลาที่มีคนรีวิวที่พักล่าสุด (object)
# - name คือ ชื่อที่พักอาศัย (object)
# - neighbourhood คือ สถานที่ใกล้เคียงที่พัก (object)
# - number_of_reviews คือ จำนวนคนรีวิวที่พัก (int64)
# - review_scores_rating คือ คะแนนรีวิวที่พัก (float64)
# - thumbnail_url คือ ภาพตัวอย่างที่พักขนาดย่อ (object)
# - zipcode คือ รหัสไปรษณีย์ (object)
# - bedrooms คือ จำนวนห้องนอน (float64)
# - beds คือ จำนวนเตียงนอน (float64)

# %% [markdown]
# # เตรียมข้อมูล

# %%
df = pd.read_csv('Airbnb_Data.csv')
df.sample(10)
# Out:
#              id  log_price property_type        room_type  \
# 12920   1101568   3.806662     Apartment     Private room
# 16583  20747756   5.991465     Apartment  Entire home/apt
# 47332  18517493   4.941642     Apartment  Entire home/apt
# 67512    339386   5.010635     Apartment  Entire home/apt
# 35407  16725749   4.477337     Apartment     Private room
# 1058    5402480   4.595120     Apartment  Entire home/apt
# 4480    4038587   4.787492     Apartment  Entire home/apt
# 12802   6093619   4.174387         House     Private room
# 68262  18341017   5.703782     Apartment  Entire home/apt
# 49826  16560212   4.007333     Apartment     Private room
#
#                                                amenities  accommodates  \
# 12920  {"Wireless Internet",Kitchen,"Smoke detector",...             2
# 16583  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             8
# 47332  {TV,"Cable TV",Internet,"Wireless Internet","W...             2
# ...

# %%
df.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
df = df.drop(['first_review', 'last_review', 'latitude', 'longitude', 'thumbnail_url', 'zipcode', 'description'], axis=1)
df
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %% [markdown]
# # จัดการทำความสะอาดข้อมูล

# %% [markdown]
# ดูค่าที่ว่างในแต่ละคอลัมน์

# %%
df.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# bedrooms                     91
# beds                        131
# dtype: int64

# %% [markdown]
# ## 1. ลบคอลัมน์ที่ไม่จำเป็น

# %% [markdown]
# ลบคอลัมน์ที่ไม่จำเป็นต่อการวิเคราะห์

# %%
df = df.dropna(subset=['bathrooms', 'host_has_profile_pic', 'host_identity_verified', 'host_since', 'bedrooms', 'beds'])
df
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %% [markdown]
# ## 2. แทนค่า null ในคอลัมน์ neighbourhood ด้วย 'Unknown'

# %% [markdown]
# แทนค่า null ด้วย Unknown เพื่อป้องกันไม่ให้เวลาใช้ค่าจากคอลัมน์ neighbourhood มาวิเคราะห์แล้วเกิด Error

# %%
df.loc[:, 'neighbourhood'] = df.loc[:, 'neighbourhood'].fillna('Unknown')

# %% [markdown]
# ## 3. เคลียร์ค่า null values

# %% [markdown]
# ลบแถวที่มีค่าในบางช่องเป็น null เพื่อป้องกันไม่ให้เวลาใช้ค่าจากคอลัมน์นั้นมาวิเคราะห์แล้วเกิด Error
#
# เนื่องจากไม่สามารถหาค่ามาแทนที่ได้ไม่งั้นจะส่งผลต่อการวิเคราะห์ข้อมูล ทำให้ข้อมูลทั้งหมดจาก 73579 ข้อมูลเหลือ 47787 ข้อมูล

# %%
df.loc[df.isna().any(axis=1)]
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 12     14066228   4.248495     Apartment     Private room
# 15      6226658   4.094345     Apartment     Private room
# 16      7499179   4.317488          Loft     Private room
# ...         ...        ...           ...              ...
# 74089   4550722   4.605170         House     Private room
# 74095   2278677   4.382027     Apartment  Entire home/apt
# 74096   7331958   3.912023     Apartment     Private room
# 74106  14549287   4.605170     Apartment     Private room
# 74109  17045948   5.273000     Apartment  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 3      {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# ...

# %%
df = df.loc[~df.isna().any(axis=1)]
df
# Out:
#              id  log_price property_type        room_type  \
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# 5      12422935   4.442651     Apartment     Private room
# 6      11825529   4.418841     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74104  14934112   4.356709     Apartment  Entire home/apt
# 74105    808802   4.248495         House     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# 2      {TV,"Cable TV","Wireless Internet","Air condit...             5
# ...

# %% [markdown]
# ## เปลี่ยนคอลัมน์ host since เป็นประเภท timestamp

# %% [markdown]
# เปลี่ยนคอลัมน์ host since จากประเภท Object เป็น timestamp เพื่อให้ง่ายต่อการใช้งานในการวิเคราะห์

# %%
df["host_since"] = pd.to_datetime(df["host_since"])
# Out:
# /var/folders/9h/2gtx9vln1pd4mxt1mqhlm6340000gn/T/ipykernel_35121/3004599045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["host_since"] = pd.to_datetime(df["host_since"])

# %% [markdown]
# ## เปลี่ยนประเภทจาก Object เป็น Categorical

# %% [markdown]
# เปลี่ยนประเภทจาก Object เป็น Categorical เพื่อให้ง่ายต่อการใช้งานในการวิเคราะห์

# %%
columns = df.columns
columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'host_since',
#        'instant_bookable', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'bedrooms', 'beds'],
#       dtype='object')

# %%
for col in columns:
    if (df[col].dtypes == 'O'):
        df[col] = pd.Categorical(df[col])
# Out:
# /var/folders/9h/2gtx9vln1pd4mxt1mqhlm6340000gn/T/ipykernel_35121/3058655606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.Categorical(df[col])
# /var/folders/9h/2gtx9vln1pd4mxt1mqhlm6340000gn/T/ipykernel_35121/3058655606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.Categorical(df[col])
# /var/folders/9h/2gtx9vln1pd4mxt1mqhlm6340000gn/T/ipykernel_35121/3058655606.py:3: SettingWithCopyWarning:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47787 entries, 1 to 74110
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      47787 non-null  int64
#  1   log_price               47787 non-null  float64
#  2   property_type           47787 non-null  category
#  3   room_type               47787 non-null  category
#  4   amenities               47787 non-null  category
#  5   accommodates            47787 non-null  int64
#  6   bathrooms               47787 non-null  float64
#  7   bed_type                47787 non-null  category
#  8   cancellation_policy     47787 non-null  category
#  9   cleaning_fee            47787 non-null  bool
#  10  city                    47787 non-null  category
#  11  host_has_profile_pic    47787 non-null  category
#  12  host_identity_verified  47787 non-null  category
#  13  host_response_rate      47787 non-null  category
# ...

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## 1. การกระจายตัวของราคาที่พัก

# %%
sns.displot(df, x='log_price', kind='hist')
# Out:
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df, x='log_price', kind='kde')
# Out:
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# จากกราฟจะเห็นว่าราคาที่พักส่วนใหญ่มีราคาอยู่ระหว่าง 10^3 ถึง 10^6

# %% [markdown]
# ## 2. ค่าเฉลี่ยของราคาที่พัก

# %%
df["log_price"].mean()
# Out:
# 4.751301963982204

# %% [markdown]
# ค่าเฉลี่ยของราคาที่พักมีค่า 10^4.75

# %% [markdown]
# ## 3. ค่าส่วนเบี่ยงมาตรฐานของราคาที่พัก

# %%
df["log_price"].std()
# Out:
# 0.675706289385357

# %% [markdown]
# ค่าส่วนเบี่ยงเบนมาตรฐานของราคาที่พักมีค่า 0.675

# %% [markdown]
# ## 4. ค่าความแปรปรวนของราคาที่พัก

# %%
df["log_price"].var()
# Out:
# 0.4565789895149278

# %% [markdown]
# ค่าความแปรปรวนของราคาที่พักมีค่า 0.45

# %% [markdown]
# ## 5. ความสัมพันธ์ของราคาที่พักกับคะแนนรีวิว

# %%
sns.relplot(df, x = "review_scores_rating", y = "log_price", kind = "line")
# Out:
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df["review_scores_rating"].corr(df.log_price, method = "spearman")
# Out:
# 0.080195463779835

# %%
df["log_price"].corr(df["review_scores_rating"], method = "pearson")
# Out:
# 0.07926846262953231

# %% [markdown]
# กราฟมีแนวโน้มว่าที่พักที่มีคะแนนรีวิวสูงมักมีราคาที่สูงกว่า
# คะแนนรีวิวและราคาที่พักมีความสัมพันธ์เชิงบวก
# ค่าสัมประสิทธิ์สหสัมพันธ์ ระหว่างคะแนนรีวิวและราคาที่พัก อยู่ที่ 0.08 หมายความว่า คะแนนรีวิวมีผลต่อราคาที่พักเพียงเล็กน้อย

# %% [markdown]
# ## 6. ความสัมพันธ์ระหว่างราคาที่พักกับจำนวนห้องนอน

# %%
sns.relplot(df, x = "bedrooms", y = "log_price", kind = "line")
# Out:
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(df, x = "bedrooms", y = "log_price", kind = "scatter")
# Out:
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df["log_price"].corr(df["bedrooms"], method = "spearman")
# Out:
# 0.43567839498647765

# %%
df["log_price"].corr(df["bedrooms"], method = "pearson")
# Out:
# 0.5034055360300418

# %% [markdown]
# กราฟมีแนวโน้มว่าที่พักที่มีจำนวนห้องนอนมากมักมีราคาที่สูงกว่า
#
# จำนวนห้องนอนและราคาที่พักมีความสัมพันธ์เชิงบวก
#
# ค่าสัมประสิทธิ์สหสัมพันธ์ ระหว่างจำนวนห้องนอนกับราคาเฉลี่ยของบ้านคือ 0.50 หมายความว่า จำนวนห้องนอนมีผลต่อราคาที่พักที่ปานกลาง

# %% [markdown]
# ## 7. การทดสอบสมมุติฐาน (Insight analysis)

# %%
mean_lprice_by_bedrooms = df.groupby('bedrooms').log_price.mean()
mean_lprice_by_bedrooms
# Out:
# bedrooms
# 0.0     4.777428
# 1.0     4.502395
# 2.0     5.228880
# 3.0     5.578561
# 4.0     5.949800
# 5.0     6.186203
# 6.0     6.409382
# 7.0     6.557992
# 8.0     6.287182
# 9.0     6.353662
# 10.0    6.067557
# Name: log_price, dtype: float64

# %% [markdown]
# ### H_0: ห้องนอน 6 ห้อง ราคาไม่แตกต่างจาก ห้องนอน 7 ห้อง ที่นัยสำคัญ 0.1
# ### H_1: ห้องนอน 7 ห้อง ราคามากกว่า ห้องนอน 6 ห้อง จริง

# %%
alpha = 0.1

# %% [markdown]
# #### กลุ่มตัวอย่าง

# %%
real_diff = mean_lprice_by_bedrooms[7] - mean_lprice_by_bedrooms[6]
real_diff
# Out:
# 0.14861073675376968

# %%
num_by_bedrooms = df.groupby('bedrooms').size()
num_by_bedrooms
# Out:
# bedrooms
# 0.0      4409
# 1.0     31457
# 2.0      7766
# 3.0      2922
# 4.0       878
# 5.0       240
# 6.0        63
# 7.0        31
# 8.0        12
# 9.0         4
# 10.0        5
# dtype: int64

# %%
num_grp_A = num_by_bedrooms[6]
num_grp_B = num_by_bedrooms[7]

# %%
df_67 = df.query('bedrooms == 6 | bedrooms == 7')

# %%
ls = []
for i in range(1000):
    grp_A = df_67.sample(num_grp_A)
    grp_B = df_67.loc[ ~df_67.index.isin( grp_A.index ), :]
    mean_log_price_diff = grp_B.log_price.mean() - grp_A.log_price.mean()
    ls.append(mean_log_price_diff)

# %%
diff_log_price_bedrooms = pd.Series(ls)
diff_log_price_bedrooms
# Out:
# 0      0.022796
# 1     -0.099569
# 2      0.077830
# 3     -0.068341
# 4     -0.080356
#          ...
# 995    0.069594
# 996    0.002028
# 997   -0.162768
# 998   -0.047581
# 999   -0.120218
# Length: 1000, dtype: float64

# %%
(diff_log_price_bedrooms >= real_diff).sum() / 1000 #p-value
# Out:
# 0.135

# %% [markdown]
# p-value สูงกว่า alpha ดังนั้นเราสามารถโต้แย้ง H_1 ได้
# เราต้องยอมรับ H_0 ว่าเหตุการณ์ที่เกิดขึ้นเป็นบังเอิญ
# (ห้องนอน 7 ห้อง ราคามากกว่า ห้องนอน 6 ห้อง บังเอิญ)

# %% [markdown]
# ## 8. ความสัมพันธ์เชิงเส้นและทิศทาง (Insight analysis)

# %% [markdown]
# หาความสัมพันธ์ของ columns ที่มีแนวโน้มของ spearman หรือ pearson มากกว่า 0.5

# %%
def pearson_spearman(df, method, ls):
    for i in range(len(df.columns) - 1):
        for j in range(i + 1, len(df.columns)):
            df_i, df_j = df.iloc[:,i], df.iloc[:,j]
            if (df_i.dtype in ['int64', 'float64'] and df_j.dtype in ['int64', 'float64']):
                temp = df_i.corr(df_j, method = method)
                if abs(temp) >= 0.5 and df_i.name + " " + df_j.name not in ls:
                    ls.append(df_i.name + " " + df_j.name)
                    print(df_i.name, df_j.name, df_i.corr(df_j, method = method))

# %%
print("---Spearman---")
ls = []
pearson_spearman(df, "spearman", ls)
# Out:
# ---Spearman---
# log_price accommodates 0.6077559615408777
# log_price beds 0.5041728089501177
# accommodates bedrooms 0.603335239355812
# accommodates beds 0.8084685618247734
# bedrooms beds 0.642156690754686

# %%
print("---Pearson---")
pearson_spearman(df, "pearson", ls)
# Out:
# ---Pearson---
# log_price bedrooms 0.5034055360300418
# bathrooms bedrooms 0.5756059415880238
# bathrooms beds 0.5111975770189229

# %%
for i in ls:
    l, r = i.split()
    print(l,r)
# Out:
# log_price accommodates
# log_price beds
# accommodates bedrooms
# accommodates beds
# bedrooms beds
# log_price bedrooms
# bathrooms bedrooms
# bathrooms beds

# %%
def plot_pearson_seaborn(string):
    i, j = string.split()
    df_i, df_j = df.loc[:,i], df.loc[:,j]
    print(i, 'and', j)
    print('Pearson' ,df_i.corr(df_j, method = "pearson"))
    print('Spearman' ,df_i.corr(df_j, method = "spearman"))
    sns.relplot(df, x = i, y = j, kind = "scatter")

# %%
plot_pearson_seaborn(ls[0])
# Out:
# log_price and accommodates
# Pearson 0.593480769884757
# Spearman 0.6077559615408777
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[1])
# Out:
# log_price and beds
# Pearson 0.4658555899507164
# Spearman 0.5041728089501177
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[2])
# Out:
# accommodates and bedrooms
# Pearson 0.7253493803527397
# Spearman 0.603335239355812
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[3])
# Out:
# accommodates and beds
# Pearson 0.8251033910955954
# Spearman 0.8084685618247734
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[4])
# Out:
# bedrooms and beds
# Pearson 0.7045252069974537
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Spearman 0.642156690754686

# %%
plot_pearson_seaborn(ls[5])
# Out:
# log_price and bedrooms
# Pearson 0.5034055360300418
# Spearman 0.43567839498647765
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[6])
# Out:
# bathrooms and bedrooms
# Pearson 0.5756059415880238
# Spearman 0.48784963071243764
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plot_pearson_seaborn(ls[7])
# Out:
# bathrooms and beds
# Pearson 0.5111975770189229
# Spearman 0.4024252598096599
# /Users/win/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# เมื่อวิเคราะห์จากหลายๆกราฟ และค่าของ pearson, spearman ดังกล่าวพบว่า columns ส่วนใหญ่ที่มีแนวโน้มความชันเป็นบวกจะมีความสัมพันธ์ในทิศทางเดียวกัน

# %% [markdown]
# ## 9. วิเคราะห์ข้อมูลตามกลุ่มที่สนใจ (Insight analysis)

# %% [markdown]
# 9.1 วิเคราะห์ค่าเฉลี่ยราคาของที่พักแต่ละประเภทที่พัก

# %%
property_log_price = df.loc[:, ["property_type", "log_price"]].groupby(["property_type"]).mean().rename(columns={"log_price": "mean_log_price"})
property_log_price
# Out:
#                     mean_log_price
# property_type
# Apartment                 4.751866
# Bed & Breakfast           4.511107
# Boat                      5.107821
# Boutique hotel            4.780398
# Bungalow                  4.776984
# Cabin                     4.620320
# Camper/RV                 4.424473
# Castle                    5.368424
# Cave                      4.909373
# Chalet                    4.848429
# Condominium               4.929335
# Dorm                      3.676296
# Earth House               4.744603
# Guest suite               4.712684
# Guesthouse                4.673365
# Hostel                    3.558946
# House                     4.721980
# Hut                       4.242541
# In-law                    4.859308
# Island                    5.010635
# Loft                      4.998298
# Other                     4.760506
# Serviced apartment        4.995226
# Tent                      3.997118
# Timeshare                 5.579740
# ...

# %% [markdown]
# จากการวิเคราะห์ประเภทของที่พักไม่ค่อยมีผลต่อจำนวนที่พักสูงสุด
# ราคาประเภทที่พักที่ราคาแพงที่สุดคือ Timeshare

# %%
max_plp = property_log_price["mean_log_price"].max()
property_log_price[property_log_price["mean_log_price"] == max_plp]
# Out:
#                mean_log_price
# property_type
# Timeshare             5.57974

# %% [markdown]
# 9.2 วิเคราะห์ค่าเฉลี่ยจำนวนคนที่เข้าพักได้สูงสุดแต่ละประเภทที่พัก

# %%
prop_acc = df.loc[:, ["property_type", "accommodates"]].groupby(["property_type"]).mean().rename(columns={"accommodates": "mean_accommodates"})
prop_acc
# Out:
#                     mean_accommodates
# property_type
# Apartment                    3.114431
# Bed & Breakfast              2.539157
# Boat                         3.177778
# Boutique hotel               2.945946
# Bungalow                     3.093190
# Cabin                        2.406780
# Camper/RV                    2.923077
# Castle                       4.846154
# Cave                         1.500000
# Chalet                       3.400000
# Condominium                  3.469955
# Dorm                         3.105769
# Earth House                  2.666667
# Guest suite                  2.656566
# Guesthouse                   2.896725
# Hostel                       3.018182
# House                        3.788061
# Hut                          2.571429
# In-law                       2.936508
# Island                       2.000000
# Loft                         3.834292
# Other                        3.491003
# Serviced apartment           3.400000
# ...

# %% [markdown]
# จากการวิเคราะห์ประเภทของที่พักมีผลต่อจำนวนคนที่เข้าพักสูงสุด
# ประเภทที่พักที่เข้าพักได้มากที่สุดคือ Villa

# %%
max_pa = prop_acc["mean_accommodates"].max()
prop_acc[prop_acc["mean_accommodates"] == max_pa]
# Out:
#                mean_accommodates
# property_type
# Villa                       5.32

# %% [markdown]
# 9.3 วิเคราะห์ค่าเฉลี่ยราคาแต่ละจำนวนคนที่เข้าพักได้สูงสุด

# %%
acc_loc = df.loc[:, ["log_price", "accommodates"]].groupby(["accommodates"]).mean().rename(columns={"log_price": "mean_log_price"})
acc_loc
# Out:
#               mean_log_price
# accommodates
# 1                   4.096264
# 2                   4.501416
# 3                   4.734784
# 4                   4.980269
# 5                   5.163231
# 6                   5.352831
# 7                   5.453122
# 8                   5.637284
# 9                   5.626796
# 10                  5.791251
# 11                  5.806449
# 12                  6.025528
# 13                  5.849381
# 14                  5.949528
# 15                  5.909940
# 16                  5.987076

# %% [markdown]
# จากการวิเคราะห์จำนวนคนที่เข้าได้สูงสุดพักมีผลต่อราคา
# จำนวนคนเข้าพักที่ราคาพักที่แพงที่สุด คือ 12 คน

# %%
max_la = acc_loc["mean_log_price"].max()
acc_loc[acc_loc["mean_log_price"] == max_la]
# Out:
#               mean_log_price
# accommodates
# 12                  6.025528

# %%
df[df['name'].isin(df['name'].value_counts().index)]
# Out:
#              id  log_price property_type        room_type  \
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# 5      12422935   4.442651     Apartment     Private room
# 6      11825529   4.418841     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74104  14934112   4.356709     Apartment  Entire home/apt
# 74105    808802   4.248495         House     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# 2      {TV,"Cable TV","Wireless Internet","Air condit...             5
# ...
